# %%
import napari
import numpy as np
from tifffile import TiffFile

# %%
viewer = napari.Viewer()
napari.run()

# %%
z_scale = 5
for layer in viewer.layers:
    layer.scale = [z_scale, 1, 1]

# %%
layer = viewer.layers['Run04_singleframe_DL2_RL50']
layer.scale = [z_scale, 1, 1]
